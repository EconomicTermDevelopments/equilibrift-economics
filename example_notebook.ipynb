# %% [markdown]
# # Equilibrift\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom equilibrift import EquilibriftCalculator\n

# %%
df = pd.read_csv("equilibrift_dataset.csv")\ndf.head()\n

# %%
calc = EquilibriftCalculator()\nresult = calc.calculate_equilibrift(df)\nresult.head()\n

# %%
result["equilibrift_index"].describe()\n

# %%
result.groupby("equilibrift_band").size()\n

# %%
result["equilibrift_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Equilibrift` index is now ready for stress testing.
